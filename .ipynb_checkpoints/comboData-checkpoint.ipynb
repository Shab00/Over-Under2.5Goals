# %%
! pip install pandas
import pandas as pd
import os
# Out:
# Requirement already satisfied: pandas in /Users/bashaar/miniconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/bashaar/miniconda3/lib/python3.12/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bashaar/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bashaar/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bashaar/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/bashaar/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Folder containing your CSV files
folder_path = 'all_data'
combined_csv_path = 'combined.csv'
csv_list = []

# %%
folder_path = 'csvFiles'
combined_csv_path = 'combined.csv'
csv_list = []

folder_path = 'csvFiles'
combined_csv_path = 'combined.csv'
csv_list = []

# Define the columns you want to keep
# Define the columns you want to keep
columns_to_keep = [
    'Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
    'HTHG', 'HTAG', 'HTR', 'Attendance', 'Referee', 'HS', 'AS', 'HST', 'AST',
    'HHW', 'AHW', 'HC', 'AC', 'HF', 'AF', 'HFKC', 'AFKC', 'HO', 'AO', 'HY', 'AY',
    'HR', 'AR', 'IWH', 'IWD', 'IWA', 'WHH', 'WHD', 'WHA'
]

# Loop through all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        try:
            # Read CSV file with specified encoding
            df = pd.read_csv(file_path, encoding='latin1', on_bad_lines='skip')
            # Filter the DataFrame to keep only the specified columns if they exist
            df_filtered = df[[col for col in columns_to_keep if col in df.columns]]
            csv_list.append(df_filtered)
        except Exception as e:
            print(f"Error reading {file_path}: {e}")

# Concatenate all DataFrames in the list
if csv_list:
    combined_df = pd.concat(csv_list, ignore_index=True)
    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv(combined_csv_path, index=False)
    print(f"Combined CSV saved to {combined_csv_path}")
else:
    print("No CSV files were combined.")
# Out:
# Combined CSV saved to combined.csv

# %%
combined_df
# Out:
#       Div        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0      E0    19/08/06      Arsenal  Aston Villa   1.0   1.0   D   0.0   0.0
# 1      E0    19/08/06       Bolton    Tottenham   2.0   0.0   H   2.0   0.0
# 2      E0    19/08/06      Everton      Watford   2.0   1.0   H   1.0   0.0
# 3      E0    19/08/06    Newcastle        Wigan   2.0   1.0   H   1.0   0.0
# 4      E0    19/08/06   Portsmouth    Blackburn   3.0   0.0   H   1.0   0.0
# ...    ..         ...          ...          ...   ...   ...  ..   ...   ...
# 12576  E0  28/05/2023      Everton  Bournemouth   1.0   0.0   H   0.0   0.0
# 12577  E0  28/05/2023        Leeds    Tottenham   1.0   4.0   A   0.0   1.0
# 12578  E0  28/05/2023    Leicester     West Ham   2.0   1.0   H   1.0   0.0
# 12579  E0  28/05/2023   Man United       Fulham   2.0   1.0   H   1.0   1.0
# 12580  E0  28/05/2023  Southampton    Liverpool   4.0   4.0   D   2.0   2.0
#
#       HTR  ...   IWA   WHH   WHD   WHA   Time  Attendance  HHW  AHW  HO  AO
# 0       D  ...  8.50  1.28  4.50  8.00    NaN         NaN  NaN  NaN NaN NaN
# 1       H  ...  2.60  2.60  3.10  2.40    NaN         NaN  NaN  NaN NaN NaN
# 2       H  ...  4.30  1.57  3.30  5.50    NaN         NaN  NaN  NaN NaN NaN
# 3       H  ...  4.30  1.72  3.20  4.33    NaN         NaN  NaN  NaN NaN NaN
# 4       H  ...  2.60  2.20  3.10  2.87    NaN         NaN  NaN  NaN NaN NaN
# ...    ..  ...   ...   ...   ...   ...    ...         ...  ...  ...  ..  ..
# 12576   D  ...  7.25  1.36  4.20  6.50  16:30         NaN  NaN  NaN NaN NaN
# 12577   A  ...  2.45  2.60  3.50  2.20  16:30         NaN  NaN  NaN NaN NaN
# 12578   H  ...  3.60  1.85  3.60  3.30  16:30         NaN  NaN  NaN NaN NaN
# 12579   D  ...  5.75  1.44  4.20  5.50  16:30         NaN  NaN  NaN NaN NaN
# 12580   D  ...  1.45  6.00  4.75  1.33  16:30         NaN  NaN  NaN NaN NaN
#
# [12581 rows x 35 columns]
