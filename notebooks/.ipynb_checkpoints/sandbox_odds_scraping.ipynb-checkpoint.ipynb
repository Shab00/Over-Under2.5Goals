# %%
import requests
import pandas as pd

BASE_URL = "https://sdp-prem-prod.premier-league-prod.pulselive.com/api/v2/matches"
competition_id = 8
season_id = 2025
all_rows = []

for mw in range(1, 39):
    params = {
        "competition": competition_id,
        "season": season_id,
        "matchweek": mw,
        "_limit": 20
    }
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    resp = requests.get(BASE_URL, params=params, headers=headers)
    js = resp.json()
    for match in js.get("data", []):
        home = match.get("homeTeam", {}).get("name", "")
        away = match.get("awayTeam", {}).get("name", "")
        home_score = match.get("homeTeam", {}).get("score", "")
        away_score = match.get("awayTeam", {}).get("score", "")
        kickoff = match.get("kickoff", "")
        venue = match.get("ground", "")
        matchweek = match.get("matchWeek", "")
        match_id = match.get("matchId", "")
        all_rows.append({
            "MatchWeek": matchweek,
            "HomeTeam": home,
            "AwayTeam": away,
            "HomeScore": home_score,
            "AwayScore": away_score,
            "Kickoff": kickoff,
            "Venue": venue,
            "MatchId": match_id
        })

df = pd.DataFrame(all_rows)
print(df.head())
df.to_csv("../data/raw/football_data/premier_league_2025_26_fixtures.csv", index=False)
# Out:
#    MatchWeek                  HomeTeam          AwayTeam HomeScore AwayScore  \
# 0          1                 Liverpool       Bournemouth         4         2
# 1          1               Aston Villa  Newcastle United         0         0
# 2          1  Brighton and Hove Albion            Fulham         1         1
# 3          1         Nottingham Forest         Brentford         3         1
# 4          1                Sunderland   West Ham United         3         0
#
#                Kickoff                             Venue  MatchId
# 0  2025-08-15 20:00:00                Anfield, Liverpool  2561895
# 1  2025-08-16 12:30:00            Villa Park, Birmingham  2561896
# 2  2025-08-16 15:00:00  American Express Stadium, Falmer  2561897
# 3  2025-08-17 14:00:00       The City Ground, Nottingham  2561898
# 4  2025-08-16 15:00:00      Stadium of Light, Sunderland  2561899
