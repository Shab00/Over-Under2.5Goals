# %%
import pandas as pd

df = pd.read_csv("../data/raw/football_data/premier_league_2025_26_fixtures.csv")

# %%
df
# Out:
#      MatchWeek                  HomeTeam          AwayTeam  HomeScore  \
# 0            1                 Liverpool       Bournemouth        4.0
# 1            1               Aston Villa  Newcastle United        0.0
# 2            1  Brighton and Hove Albion            Fulham        1.0
# 3            1         Nottingham Forest         Brentford        3.0
# 4            1                Sunderland   West Ham United        3.0
# ..         ...                       ...               ...        ...
# 375         38           Manchester City       Aston Villa        NaN
# 376         38         Nottingham Forest       Bournemouth        NaN
# 377         38                Sunderland           Chelsea        NaN
# 378         38         Tottenham Hotspur           Everton        NaN
# 379         38           West Ham United      Leeds United        NaN
#
#      AwayScore              Kickoff                              Venue  \
# ...
