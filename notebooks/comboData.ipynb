# %%
import pandas as pd
import os

# %%
folder_path = 'all_data'
combined_csv_path = 'combined.csv'
csv_list = []

# %%
folder_path = '../data/raw/csvFiles'
combined_csv_path = 'combined.csv'
csv_list = []

folder_path = '../data/raw/csvFiles'
combined_csv_path = 'combined.csv'
csv_list = []

columns_to_keep = [
    'Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
    'HTHG', 'HTAG', 'HTR', 'Attendance', 'Referee', 'HS', 'AS', 'HST', 'AST',
    'HHW', 'AHW', 'HC', 'AC', 'HF', 'AF', 'HFKC', 'AFKC', 'HO', 'AO', 'HY', 'AY',
    'HR', 'AR', 'IWH', 'IWD', 'IWA', 'WHH', 'WHD', 'WHA', 'B365H', 'B365D', 'B365A',
    'PH', 'PD', 'PA', 'AvgH', 'AvgD', 'AvgA', 'MaxH', 'MaxD', 'MaxA',
    'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5',
    'GB>2.5', 'GB<2.5', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5',
    'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5'
]

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        try:
            df = pd.read_csv(file_path, encoding='latin1', on_bad_lines='skip')
            df_filtered = df[[col for col in columns_to_keep if col in df.columns]]
            csv_list.append(df_filtered)
        except Exception as e:
            print(f"Error reading {file_path}: {e}")

if csv_list:
    combined_df = pd.concat(csv_list, ignore_index=True)
    combined_df.to_csv(combined_csv_path, index=False)
    print(f"Combined CSV saved to {combined_csv_path}")
else:
    print("No CSV files were combined.")
# Out:
# Combined CSV saved to combined.csv

# %%
combined_df
# Out:
#       Div       Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0      E0        NaT      Arsenal  Aston Villa   1.0   1.0   D   0.0   0.0
# 1      E0        NaT       Bolton    Tottenham   2.0   0.0   H   2.0   0.0
# 2      E0        NaT      Everton      Watford   2.0   1.0   H   1.0   0.0
# 3      E0        NaT    Newcastle        Wigan   2.0   1.0   H   1.0   0.0
# 4      E0        NaT   Portsmouth    Blackburn   3.0   0.0   H   1.0   0.0
# ...    ..        ...          ...          ...   ...   ...  ..   ...   ...
# 12926  E0 2023-05-28      Everton  Bournemouth   1.0   0.0   H   0.0   0.0
# 12927  E0 2023-05-28        Leeds    Tottenham   1.0   4.0   A   0.0   1.0
# 12928  E0 2023-05-28    Leicester     West Ham   2.0   1.0   H   1.0   0.0
# 12929  E0 2023-05-28   Man United       Fulham   2.0   1.0   H   1.0   1.0
# 12930  E0 2023-05-28  Southampton    Liverpool   4.0   4.0   D   2.0   2.0
#
#       HTR  ... P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5  Attendance  HHW  \
# 0       D  ...   NaN      NaN      NaN      NaN      NaN         NaN  NaN
# 1       H  ...   NaN      NaN      NaN      NaN      NaN         NaN  NaN
# 2       H  ...   NaN      NaN      NaN      NaN      NaN         NaN  NaN
# 3       H  ...   NaN      NaN      NaN      NaN      NaN         NaN  NaN
# 4       H  ...   NaN      NaN      NaN      NaN      NaN         NaN  NaN
# ...    ..  ...   ...      ...      ...      ...      ...         ...  ...
# 12926   D  ...  2.26     1.74     2.29     1.68     2.22         NaN  NaN
# 12927   A  ...  2.65     1.52     2.72     1.50     2.60         NaN  NaN
# 12928   H  ...  2.23     1.74     2.28     1.68     2.21         NaN  NaN
# 12929   D  ...  2.61     1.53     2.80     1.49     2.63         NaN  NaN
# 12930   D  ...  3.01     1.42     3.12     1.39     3.01         NaN  NaN
#
#        AHW  HO  AO
# 0      NaN NaN NaN
# 1      NaN NaN NaN
# 2      NaN NaN NaN
# 3      NaN NaN NaN
# 4      NaN NaN NaN
# ...    ...  ..  ..
# 12926  NaN NaN NaN
# 12927  NaN NaN NaN
# 12928  NaN NaN NaN
# 12929  NaN NaN NaN
# 12930  NaN NaN NaN
#
# [12931 rows x 59 columns]

# %%
combined_df['Date'] = pd.to_datetime(combined_df['Date'], format='%d/%m/%Y', errors='coerce')
print("Year range:", combined_df['Date'].dt.year.min(), "to", combined_df['Date'].dt.year.max())
# Out:
# Year range: 2002.0 to 2025.0
